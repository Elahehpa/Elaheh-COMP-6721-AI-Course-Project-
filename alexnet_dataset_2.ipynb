# %%
#Importing Libraries
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import image
from matplotlib import pyplot
import time
import os
import torch
import torchvision
from torch.utils.data import random_split
import torchvision.models as models
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder

# %%
# !unzip "/content/drive/MyDrive/TrashBox_train_set.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: TrashBox_train_set/medical/medical 1322.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1322.jpg
#   inflating: TrashBox_train_set/medical/medical 1444.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1444.jpg
#   inflating: TrashBox_train_set/medical/medical 746.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 746.jpg
#   inflating: TrashBox_train_set/medical/medical 1875.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1875.jpg
#   inflating: TrashBox_train_set/medical/medical 1861.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1861.jpg
#   inflating: TrashBox_train_set/medical/medical 593.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 593.jpg
#   inflating: TrashBox_train_set/medical/medical 1691.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1691.jpg
#   inflating: TrashBox_train_set/medical/medical 587.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 587.jpg
#   inflating: TrashBox_train_set/medical/medical 1685.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1685.jpg
#   inflating: TrashBox_train_set/medical/medical 1108.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1108.jpg
#   inflating: TrashBox_train_set/medical/medical 578.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 578.jpg
#   inflating: TrashBox_train_set/medical/medical 1134.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1134.jpg
#   inflating: TrashBox_train_set/medical/medical 236.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 236.jpg
#   inflating: TrashBox_train_set/medical/medical 1652.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1652.jpg
#   inflating: TrashBox_train_set/medical/medical 544.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 544.jpg
#   inflating: TrashBox_train_set/medical/medical 1646.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1646.jpg
#   inflating: TrashBox_train_set/medical/medical 222.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 222.jpg
#   inflating: TrashBox_train_set/medical/medical 1901.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1901.jpg
#   inflating: TrashBox_train_set/medical/medical 1915.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1915.jpg
#   inflating: TrashBox_train_set/medical/medical 381.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 381.jpg
#   inflating: TrashBox_train_set/medical/medical 1083.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1083.jpg
#   inflating: TrashBox_train_set/medical/medical 1929.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1929.jpg
#   inflating: TrashBox_train_set/medical/medical 395.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 395.jpg
#   inflating: TrashBox_train_set/medical/medical 1068.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1068.jpg
#   inflating: TrashBox_train_set/medical/medical 1040.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1040.jpg
#   inflating: TrashBox_train_set/medical/medical 1726.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1726.jpg
#   inflating: TrashBox_train_set/medical/medical 33.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 33.jpg
#   inflating: TrashBox_train_set/medical/medical 356.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 356.jpg
#   inflating: TrashBox_train_set/medical/medical 1054.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1054.jpg
#   inflating: TrashBox_train_set/medical/medical 801.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 801.jpg
#   inflating: TrashBox_train_set/medical/medical 815.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 815.jpg
#   inflating: TrashBox_train_set/medical/medical 1281.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1281.jpg
#   inflating: TrashBox_train_set/medical/medical 183.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 183.jpg
#   inflating: TrashBox_train_set/medical/medical 1295.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1295.jpg
#   inflating: TrashBox_train_set/medical/medical 197.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 197.jpg
#   inflating: TrashBox_train_set/medical/medical 829.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 829.jpg
#   inflating: TrashBox_train_set/medical/medical 1518.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1518.jpg
#   inflating: TrashBox_train_set/medical/medical 168.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 168.jpg
#   inflating: TrashBox_train_set/medical/medical 626.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 626.jpg
#   inflating: TrashBox_train_set/medical/medical 1524.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1524.jpg
#   inflating: TrashBox_train_set/medical/medical 1242.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1242.jpg
#   inflating: TrashBox_train_set/medical/medical 140.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 140.jpg
#   inflating: TrashBox_train_set/medical/medical 1256.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1256.jpg
#   inflating: TrashBox_train_set/medical/medical 154.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 154.jpg
#   inflating: TrashBox_train_set/medical/medical 632.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 632.jpg
#   inflating: TrashBox_train_set/medical/medical 1530.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1530.jpg
#   inflating: TrashBox_train_set/medical/medical 142.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 142.jpg
#   inflating: TrashBox_train_set/medical/medical 1240.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1240.jpg
#   inflating: TrashBox_train_set/medical/medical 624.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 624.jpg
#   inflating: TrashBox_train_set/medical/medical 1532.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1532.jpg
#   inflating: TrashBox_train_set/medical/medical 630.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 630.jpg
#   inflating: TrashBox_train_set/medical/medical 156.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 156.jpg
#   inflating: TrashBox_train_set/medical/medical 8.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 8.jpg
#   inflating: TrashBox_train_set/medical/medical 1268.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1268.jpg
#   inflating: TrashBox_train_set/medical/medical 1283.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1283.jpg
#   inflating: TrashBox_train_set/medical/medical 195.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 195.jpg
#   inflating: TrashBox_train_set/medical/medical 803.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 803.jpg
#   inflating: TrashBox_train_set/medical/medical 817.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 817.jpg
#   inflating: TrashBox_train_set/medical/medical 426.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 426.jpg
#   inflating: TrashBox_train_set/medical/medical 1724.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1724.jpg
#   inflating: TrashBox_train_set/medical/medical 340.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 340.jpg
#   inflating: TrashBox_train_set/medical/medical 1056.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1056.jpg
#   inflating: TrashBox_train_set/medical/medical 31.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 31.jpg
#   inflating: TrashBox_train_set/medical/medical 432.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 432.jpg
#   inflating: TrashBox_train_set/medical/medical 1730.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1730.jpg
#   inflating: TrashBox_train_set/medical/medical 1718.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1718.jpg
#   inflating: TrashBox_train_set/medical/medical 368.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 368.jpg
#   inflating: TrashBox_train_set/medical/medical 1095.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1095.jpg
#   inflating: TrashBox_train_set/medical/medical 1917.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1917.jpg
#   inflating: TrashBox_train_set/medical/medical 1888.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1888.jpg
#   inflating: TrashBox_train_set/medical/medical 1650.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1650.jpg
#   inflating: TrashBox_train_set/medical/medical 552.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 552.jpg
#   inflating: TrashBox_train_set/medical/medical 234.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 234.jpg
#   inflating: TrashBox_train_set/medical/medical 1136.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1136.jpg
#   inflating: TrashBox_train_set/medical/medical 220.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 220.jpg
#   inflating: TrashBox_train_set/medical/medical 1122.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1122.jpg
#   inflating: TrashBox_train_set/medical/medical 1644.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1644.jpg
#   inflating: TrashBox_train_set/medical/medical 546.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 546.jpg
#   inflating: TrashBox_train_set/medical/medical 208.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 208.jpg
#   inflating: TrashBox_train_set/medical/medical 1678.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1678.jpg
#   inflating: TrashBox_train_set/medical/medical 1693.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1693.jpg
#   inflating: TrashBox_train_set/medical/medical 1687.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1687.jpg
#   inflating: TrashBox_train_set/medical/medical 585.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 585.jpg
#   inflating: TrashBox_train_set/medical/medical 1877.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1877.jpg
#   inflating: TrashBox_train_set/medical/medical 1863.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1863.jpg
#   inflating: TrashBox_train_set/medical/medical 1334.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1334.jpg
#   inflating: TrashBox_train_set/medical/medical 750.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 750.jpg
#   inflating: TrashBox_train_set/medical/medical 1452.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1452.jpg
#   inflating: TrashBox_train_set/medical/medical 988.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 988.jpg
#   inflating: TrashBox_train_set/medical/medical 744.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 744.jpg
#   inflating: TrashBox_train_set/medical/medical 1446.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1446.jpg
#   inflating: TrashBox_train_set/medical/medical 1320.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1320.jpg
#   inflating: TrashBox_train_set/medical/medical 1308.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1308.jpg
#   inflating: TrashBox_train_set/medical/medical 778.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 778.jpg
#   inflating: TrashBox_train_set/medical/medical 793.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 793.jpg
#   inflating: TrashBox_train_set/medical/medical 1491.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1491.jpg
#   inflating: TrashBox_train_set/medical/medical 787.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 787.jpg
#   inflating: TrashBox_train_set/medical/medical 1485.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1485.jpg
#   inflating: TrashBox_train_set/medical/medical 977.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 977.jpg
#   inflating: TrashBox_train_set/medical/medical 963.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 963.jpg
#   inflating: TrashBox_train_set/medical/medical 962.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 962.jpg
#   inflating: TrashBox_train_set/medical/medical 976.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 976.jpg
#   inflating: TrashBox_train_set/medical/medical 1484.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1484.jpg
#   inflating: TrashBox_train_set/medical/medical 786.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 786.jpg
#   inflating: TrashBox_train_set/medical/medical 1490.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1490.jpg
#   inflating: TrashBox_train_set/medical/medical 792.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 792.jpg
#   inflating: TrashBox_train_set/medical/medical 779.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 779.jpg
#   inflating: TrashBox_train_set/medical/medical 1309.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1309.jpg
#   inflating: TrashBox_train_set/medical/medical 1447.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1447.jpg
#   inflating: TrashBox_train_set/medical/medical 745.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 745.jpg
#   inflating: TrashBox_train_set/medical/medical 1321.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1321.jpg
#   inflating: TrashBox_train_set/medical/medical 1335.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1335.jpg
#   inflating: TrashBox_train_set/medical/medical 989.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 989.jpg
#   inflating: TrashBox_train_set/medical/medical 1453.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1453.jpg
#   inflating: TrashBox_train_set/medical/medical 751.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 751.jpg
#   inflating: TrashBox_train_set/medical/medical 1876.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1876.jpg
#   inflating: TrashBox_train_set/medical/medical 584.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 584.jpg
#   inflating: TrashBox_train_set/medical/medical 1686.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1686.jpg
#   inflating: TrashBox_train_set/medical/medical 590.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 590.jpg
#   inflating: TrashBox_train_set/medical/medical 1692.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1692.jpg
#   inflating: TrashBox_train_set/medical/medical 1679.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1679.jpg
#   inflating: TrashBox_train_set/medical/medical 209.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 209.jpg
#   inflating: TrashBox_train_set/medical/medical 1645.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1645.jpg
#   inflating: TrashBox_train_set/medical/medical 553.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 553.jpg
#   inflating: TrashBox_train_set/medical/medical 1651.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1651.jpg
#   inflating: TrashBox_train_set/medical/medical 1889.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1889.jpg
#   inflating: TrashBox_train_set/medical/medical 1137.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1137.jpg
#   inflating: TrashBox_train_set/medical/medical 1916.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1916.jpg
#   inflating: TrashBox_train_set/medical/medical 1902.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1902.jpg
#   inflating: TrashBox_train_set/medical/medical 396.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 396.jpg
#   inflating: TrashBox_train_set/medical/medical 382.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 382.jpg
#   inflating: TrashBox_train_set/medical/medical 1080.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1080.jpg
#   inflating: TrashBox_train_set/medical/medical 369.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 369.jpg
#   inflating: TrashBox_train_set/medical/medical 18.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 18.jpg
#   inflating: TrashBox_train_set/medical/medical 30.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 30.jpg
#   inflating: TrashBox_train_set/medical/medical 355.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 355.jpg
#   inflating: TrashBox_train_set/medical/medical 1057.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1057.jpg
#   inflating: TrashBox_train_set/medical/medical 1725.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1725.jpg
#   inflating: TrashBox_train_set/medical/medical 341.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 341.jpg
#   inflating: TrashBox_train_set/medical/medical 24.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 24.jpg
#   inflating: TrashBox_train_set/medical/medical 816.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 816.jpg
#   inflating: TrashBox_train_set/medical/medical 1296.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1296.jpg
#   inflating: TrashBox_train_set/medical/medical 194.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 194.jpg
#   inflating: TrashBox_train_set/medical/medical 1282.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1282.jpg
#   inflating: TrashBox_train_set/medical/medical 180.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 180.jpg
#   inflating: TrashBox_train_set/medical/medical 1269.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1269.jpg
#   inflating: TrashBox_train_set/medical/medical 619.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 619.jpg
#   inflating: TrashBox_train_set/medical/medical 631.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 631.jpg
#   inflating: TrashBox_train_set/medical/medical 1533.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1533.jpg
#   inflating: TrashBox_train_set/medical/medical 1255.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1255.jpg
#   inflating: TrashBox_train_set/medical/medical 157.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 157.jpg
#   inflating: TrashBox_train_set/medical/medical 1241.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1241.jpg
#   inflating: TrashBox_train_set/medical/medical 143.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 143.jpg
#   inflating: TrashBox_train_set/medical/medical 625.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 625.jpg
#   inflating: TrashBox_train_set/medical/medical 621.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 621.jpg
#   inflating: TrashBox_train_set/medical/medical 1523.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1523.jpg
#   inflating: TrashBox_train_set/medical/medical 1245.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1245.jpg
#   inflating: TrashBox_train_set/medical/medical 147.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 147.jpg
#   inflating: TrashBox_train_set/medical/medical 1251.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1251.jpg
#   inflating: TrashBox_train_set/medical/medical 153.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 153.jpg
#   inflating: TrashBox_train_set/medical/medical 635.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 635.jpg
#   inflating: TrashBox_train_set/medical/medical 1537.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1537.jpg
#   inflating: TrashBox_train_set/medical/medical 806.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 806.jpg
#   inflating: TrashBox_train_set/medical/medical 812.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 812.jpg
#   inflating: TrashBox_train_set/medical/medical 1286.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1286.jpg
#   inflating: TrashBox_train_set/medical/medical 184.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 184.jpg
#   inflating: TrashBox_train_set/medical/medical 190.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 190.jpg
#   inflating: TrashBox_train_set/medical/medical 379.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 379.jpg
#   inflating: TrashBox_train_set/medical/medical 1709.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1709.jpg
#   inflating: TrashBox_train_set/medical/medical 20.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 20.jpg
#   inflating: TrashBox_train_set/medical/medical 345.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 345.jpg
#   inflating: TrashBox_train_set/medical/medical 1047.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1047.jpg
#   inflating: TrashBox_train_set/medical/medical 1735.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1735.jpg
#   inflating: TrashBox_train_set/medical/medical 437.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 437.jpg
#   inflating: TrashBox_train_set/medical/medical 1053.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1053.jpg
#   inflating: TrashBox_train_set/medical/medical 34.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 34.jpg
#   inflating: TrashBox_train_set/medical/medical 1906.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1906.jpg
#   inflating: TrashBox_train_set/medical/medical 386.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 386.jpg
#   inflating: TrashBox_train_set/medical/medical 1084.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1084.jpg
#   inflating: TrashBox_train_set/medical/medical 392.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 392.jpg
#   inflating: TrashBox_train_set/medical/medical 1669.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1669.jpg
#   inflating: TrashBox_train_set/medical/medical 557.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 557.jpg
#   inflating: TrashBox_train_set/medical/medical 1655.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1655.jpg
#   inflating: TrashBox_train_set/medical/medical 1899.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1899.jpg
#   inflating: TrashBox_train_set/medical/medical 1127.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1127.jpg
#   inflating: TrashBox_train_set/medical/medical 225.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 225.jpg
#   inflating: TrashBox_train_set/medical/medical 1872.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1872.jpg
#   inflating: TrashBox_train_set/medical/medical 1866.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1866.jpg
#   inflating: TrashBox_train_set/medical/medical 594.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 594.jpg
#   inflating: TrashBox_train_set/medical/medical 769.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 769.jpg
#   inflating: TrashBox_train_set/medical/medical 1319.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1319.jpg
#   inflating: TrashBox_train_set/medical/medical 1457.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1457.jpg
#   inflating: TrashBox_train_set/medical/medical 755.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 755.jpg
#   inflating: TrashBox_train_set/medical/medical 1331.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1331.jpg
#   inflating: TrashBox_train_set/medical/medical 1325.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1325.jpg
#   inflating: TrashBox_train_set/medical/medical 1443.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1443.jpg
#   inflating: TrashBox_train_set/medical/medical 741.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 741.jpg
#   inflating: TrashBox_train_set/medical/medical 999.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 999.jpg
#   inflating: TrashBox_train_set/medical/medical 966.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 966.jpg
#   inflating: TrashBox_train_set/medical/medical 1494.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1494.jpg
#   inflating: TrashBox_train_set/medical/medical 796.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 796.jpg
#   inflating: TrashBox_train_set/medical/medical 782.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 782.jpg
#   inflating: TrashBox_train_set/medical/medical 783.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 783.jpg
#   inflating: TrashBox_train_set/medical/medical 1481.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1481.jpg
#   inflating: TrashBox_train_set/medical/medical 797.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 797.jpg
#   inflating: TrashBox_train_set/medical/medical 1495.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1495.jpg
#   inflating: TrashBox_train_set/medical/medical 967.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 967.jpg
#   inflating: TrashBox_train_set/medical/medical 1324.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1324.jpg
#   inflating: TrashBox_train_set/medical/medical 998.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 998.jpg
#   inflating: TrashBox_train_set/medical/medical 740.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 740.jpg
#   inflating: TrashBox_train_set/medical/medical 1442.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1442.jpg
#   inflating: TrashBox_train_set/medical/medical 754.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 754.jpg
#   inflating: TrashBox_train_set/medical/medical 1456.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1456.jpg
#   inflating: TrashBox_train_set/medical/medical 1318.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1318.jpg
#   inflating: TrashBox_train_set/medical/medical 768.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 768.jpg
#   inflating: TrashBox_train_set/medical/medical 1683.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1683.jpg
#   inflating: TrashBox_train_set/medical/medical 581.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 581.jpg
#   inflating: TrashBox_train_set/medical/medical 1867.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1867.jpg
#   inflating: TrashBox_train_set/medical/medical 1873.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1873.jpg
#   inflating: TrashBox_train_set/medical/medical 1640.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1640.jpg
#   inflating: TrashBox_train_set/medical/medical 1898.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1898.jpg
#   inflating: TrashBox_train_set/medical/medical 224.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 224.jpg
#   inflating: TrashBox_train_set/medical/medical 1126.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1126.jpg
#   inflating: TrashBox_train_set/medical/medical 1132.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1132.jpg
#   inflating: TrashBox_train_set/medical/medical 1654.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1654.jpg
#   inflating: TrashBox_train_set/medical/medical 556.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 556.jpg
#   inflating: TrashBox_train_set/medical/medical 218.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 218.jpg
#   inflating: TrashBox_train_set/medical/medical 1668.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1668.jpg
#   inflating: TrashBox_train_set/medical/medical 1091.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1091.jpg
#   inflating: TrashBox_train_set/medical/medical 393.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 393.jpg
#   inflating: TrashBox_train_set/medical/medical 1085.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1085.jpg
#   inflating: TrashBox_train_set/medical/medical 1913.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1913.jpg
#   inflating: TrashBox_train_set/medical/medical 1907.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1907.jpg
#   inflating: TrashBox_train_set/medical/medical 436.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 436.jpg
#   inflating: TrashBox_train_set/medical/medical 1734.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1734.jpg
#   inflating: TrashBox_train_set/medical/medical 35.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 35.jpg
#   inflating: TrashBox_train_set/medical/medical 350.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 350.jpg
#   inflating: TrashBox_train_set/medical/medical 1046.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1046.jpg
#   inflating: TrashBox_train_set/medical/medical 422.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 422.jpg
#   inflating: TrashBox_train_set/medical/medical 1720.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1720.jpg
#   inflating: TrashBox_train_set/medical/medical 1293.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1293.jpg
#   inflating: TrashBox_train_set/medical/medical 185.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 185.jpg
#   inflating: TrashBox_train_set/medical/medical 813.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 813.jpg
#   inflating: TrashBox_train_set/medical/medical 152.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 152.jpg
#   inflating: TrashBox_train_set/medical/medical 1250.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1250.jpg
#   inflating: TrashBox_train_set/medical/medical 1536.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1536.jpg
#   inflating: TrashBox_train_set/medical/medical 634.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 634.jpg
#   inflating: TrashBox_train_set/medical/medical 620.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 620.jpg
#   inflating: TrashBox_train_set/medical/medical 146.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 146.jpg
#   inflating: TrashBox_train_set/medical/medical 1244.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1244.jpg
#   inflating: TrashBox_train_set/medical/medical 608.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 608.jpg
#   inflating: TrashBox_train_set/medical/medical 1278.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1278.jpg
#   inflating: TrashBox_train_set/medical/medical 1508.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1508.jpg
#   inflating: TrashBox_train_set/medical/medical 178.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 178.jpg
#   inflating: TrashBox_train_set/medical/medical 636.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 636.jpg
#   inflating: TrashBox_train_set/medical/medical 1534.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1534.jpg
#   inflating: TrashBox_train_set/medical/medical 1252.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1252.jpg
#   inflating: TrashBox_train_set/medical/medical 150.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 150.jpg
#   inflating: TrashBox_train_set/medical/medical 1246.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1246.jpg
#   inflating: TrashBox_train_set/medical/medical 144.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 144.jpg
#   inflating: TrashBox_train_set/medical/medical 1520.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1520.jpg
#   inflating: TrashBox_train_set/medical/medical 811.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 811.jpg
#   inflating: TrashBox_train_set/medical/medical 805.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 805.jpg
#   inflating: TrashBox_train_set/medical/medical 839.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 839.jpg
#   inflating: TrashBox_train_set/medical/medical 408.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 408.jpg
#   inflating: TrashBox_train_set/medical/medical 352.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 352.jpg
#   inflating: TrashBox_train_set/medical/medical 1050.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1050.jpg
#   inflating: TrashBox_train_set/medical/medical 37.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 37.jpg
#   inflating: TrashBox_train_set/medical/medical 1736.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1736.jpg
#   inflating: TrashBox_train_set/medical/medical 1722.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1722.jpg
#   inflating: TrashBox_train_set/medical/medical 23.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 23.jpg
#   inflating: TrashBox_train_set/medical/medical 346.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 346.jpg
#   inflating: TrashBox_train_set/medical/medical 1044.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1044.jpg
#   inflating: TrashBox_train_set/medical/medical 1911.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1911.jpg
#   inflating: TrashBox_train_set/medical/medical 1905.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1905.jpg
#   inflating: TrashBox_train_set/medical/medical 391.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 391.jpg
#   inflating: TrashBox_train_set/medical/medical 1093.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1093.jpg
#   inflating: TrashBox_train_set/medical/medical 1939.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1939.jpg
#   inflating: TrashBox_train_set/medical/medical 385.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 385.jpg
#   inflating: TrashBox_train_set/medical/medical 1087.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1087.jpg
#   inflating: TrashBox_train_set/medical/medical 1118.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1118.jpg
#   inflating: TrashBox_train_set/medical/medical 1124.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1124.jpg
#   inflating: TrashBox_train_set/medical/medical 226.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 226.jpg
#   inflating: TrashBox_train_set/medical/medical 540.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 540.jpg
#   inflating: TrashBox_train_set/medical/medical 1642.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1642.jpg
#   inflating: TrashBox_train_set/medical/medical 554.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 554.jpg
#   inflating: TrashBox_train_set/medical/medical 1656.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1656.jpg
#   inflating: TrashBox_train_set/medical/medical 1130.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1130.jpg
#   inflating: TrashBox_train_set/medical/medical 232.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 232.jpg
#   inflating: TrashBox_train_set/medical/medical 1865.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1865.jpg
#   inflating: TrashBox_train_set/medical/medical 1871.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1871.jpg
#   inflating: TrashBox_train_set/medical/medical 583.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 583.jpg
#   inflating: TrashBox_train_set/medical/medical 1681.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1681.jpg
#   inflating: TrashBox_train_set/medical/medical 1859.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1859.jpg
#   inflating: TrashBox_train_set/medical/medical 1695.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1695.jpg
#   inflating: TrashBox_train_set/medical/medical 1468.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1468.jpg
#   inflating: TrashBox_train_set/medical/medical 1440.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1440.jpg
#   inflating: TrashBox_train_set/medical/medical 742.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 742.jpg
#   inflating: TrashBox_train_set/medical/medical 1326.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1326.jpg
#   inflating: TrashBox_train_set/medical/medical 1332.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1332.jpg
#   inflating: TrashBox_train_set/medical/medical 1454.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1454.jpg
#   inflating: TrashBox_train_set/medical/medical 756.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 756.jpg
#   inflating: TrashBox_train_set/medical/medical 965.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 965.jpg
#   inflating: TrashBox_train_set/medical/medical 971.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 971.jpg
#   inflating: TrashBox_train_set/medical/medical 959.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 959.jpg
#   inflating: TrashBox_train_set/medical/medical 1497.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1497.jpg
#   inflating: TrashBox_train_set/medical/medical 795.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 795.jpg
#   inflating: TrashBox_train_set/medical/medical 1496.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1496.jpg
#   inflating: TrashBox_train_set/medical/medical 780.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 780.jpg
#   inflating: TrashBox_train_set/medical/medical 1482.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1482.jpg
#   inflating: TrashBox_train_set/medical/medical 958.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 958.jpg
#   inflating: TrashBox_train_set/medical/medical 970.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 970.jpg
#   inflating: TrashBox_train_set/medical/medical 1333.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1333.jpg
#   inflating: TrashBox_train_set/medical/medical 1455.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1455.jpg
#   inflating: TrashBox_train_set/medical/medical 743.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 743.jpg
#   inflating: TrashBox_train_set/medical/medical 1441.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1441.jpg
#   inflating: TrashBox_train_set/medical/medical 1327.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1327.jpg
#   inflating: TrashBox_train_set/medical/medical 1469.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1469.jpg
#   inflating: TrashBox_train_set/medical/medical 1694.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1694.jpg
#   inflating: TrashBox_train_set/medical/medical 596.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 596.jpg
#   inflating: TrashBox_train_set/medical/medical 1858.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1858.jpg
#   inflating: TrashBox_train_set/medical/medical 1680.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1680.jpg
#   inflating: TrashBox_train_set/medical/medical 582.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 582.jpg
#   inflating: TrashBox_train_set/medical/medical 1870.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1870.jpg
#   inflating: TrashBox_train_set/medical/medical 1864.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1864.jpg
#   inflating: TrashBox_train_set/medical/medical 1657.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1657.jpg
#   inflating: TrashBox_train_set/medical/medical 555.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 555.jpg
#   inflating: TrashBox_train_set/medical/medical 233.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 233.jpg
#   inflating: TrashBox_train_set/medical/medical 1131.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1131.jpg
#   inflating: TrashBox_train_set/medical/medical 227.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 227.jpg
#   inflating: TrashBox_train_set/medical/medical 1125.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1125.jpg
#   inflating: TrashBox_train_set/medical/medical 1643.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1643.jpg
#   inflating: TrashBox_train_set/medical/medical 541.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 541.jpg
#   inflating: TrashBox_train_set/medical/medical 569.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 569.jpg
#   inflating: TrashBox_train_set/medical/medical 1119.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1119.jpg
#   inflating: TrashBox_train_set/medical/medical 1938.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1938.jpg
#   inflating: TrashBox_train_set/medical/medical 1086.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1086.jpg
#   inflating: TrashBox_train_set/medical/medical 384.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 384.jpg
#   inflating: TrashBox_train_set/medical/medical 1092.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1092.jpg
#   inflating: TrashBox_train_set/medical/medical 390.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 390.jpg
#   inflating: TrashBox_train_set/medical/medical 1910.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1910.jpg
#   inflating: TrashBox_train_set/medical/medical 421.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 421.jpg
#   inflating: TrashBox_train_set/medical/medical 1723.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1723.jpg
#   inflating: TrashBox_train_set/medical/medical 1045.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1045.jpg
#   inflating: TrashBox_train_set/medical/medical 347.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 347.jpg
#   inflating: TrashBox_train_set/medical/medical 22.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 22.jpg
#   inflating: TrashBox_train_set/medical/medical 36.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 36.jpg
#   inflating: TrashBox_train_set/medical/medical 1051.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1051.jpg
#   inflating: TrashBox_train_set/medical/medical 353.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 353.jpg
#   inflating: TrashBox_train_set/medical/medical 435.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 435.jpg
#   inflating: TrashBox_train_set/medical/medical 1737.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1737.jpg
#   inflating: TrashBox_train_set/medical/medical 1079.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1079.jpg
#   inflating: TrashBox_train_set/medical/medical 409.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 409.jpg
#   inflating: TrashBox_train_set/medical/medical 186.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 186.jpg
#   inflating: TrashBox_train_set/medical/medical 838.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 838.jpg
#   inflating: TrashBox_train_set/medical/medical 192.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 192.jpg
#   inflating: TrashBox_train_set/medical/medical 804.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 804.jpg
#   inflating: TrashBox_train_set/medical/medical 810.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 810.jpg
#   inflating: TrashBox_train_set/medical/medical 1247.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1247.jpg
#   inflating: TrashBox_train_set/medical/medical 1521.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1521.jpg
#   inflating: TrashBox_train_set/medical/medical 1535.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1535.jpg
#   inflating: TrashBox_train_set/medical/medical 637.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 637.jpg
#   inflating: TrashBox_train_set/medical/medical 151.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 151.jpg
#   inflating: TrashBox_train_set/medical/medical 1253.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1253.jpg
#   inflating: TrashBox_train_set/medical/medical 1509.jpg
#   inflating: __MACOSX/TrashBox_train_set/medical/._medical 1509.jpg
#   inflating: TrashBox_train_set/plastic/plastic 1278.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 1278.jpg
#   inflating: TrashBox_train_set/plastic/plastic 366.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 366.jpg
#   inflating: TrashBox_train_set/plastic/plastic 372.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 372.jpg
#   inflating: TrashBox_train_set/plastic/plastic 414.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 414.jpg
#   inflating: TrashBox_train_set/plastic/plastic 1244.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 1244.jpg
#   inflating: TrashBox_train_set/plastic/plastic 1522.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 1522.jpg
#   inflating: TrashBox_train_set/plastic/plastic 1250.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 1250.jpg
#   inflating: TrashBox_train_set/plastic/plastic 1293.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 1293.jpg
#   inflating: TrashBox_train_set/plastic/plastic 2215.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 2215.jpg
#   inflating: TrashBox_train_set/plastic/plastic 164.jpg
# ...
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 342.jpg
#   inflating: TrashBox_train_set/plastic/plastic 2033.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 2033.jpg
#   inflating: TrashBox_train_set/plastic/plastic 424.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 424.jpg
#   inflating: TrashBox_train_set/plastic/plastic 430.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 430.jpg
#   inflating: TrashBox_train_set/plastic/plastic 1248.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 1248.jpg
#   inflating: TrashBox_train_set/plastic/plastic 2027.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 2027.jpg
#   inflating: TrashBox_train_set/plastic/plastic 395.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 395.jpg
#   inflating: TrashBox_train_set/plastic/plastic 1062.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 1062.jpg
#   inflating: TrashBox_train_set/plastic/plastic 1710.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 1710.jpg
#   inflating: TrashBox_train_set/plastic/plastic 2219.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 2219.jpg
#   inflating: TrashBox_train_set/plastic/plastic 1076.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 1076.jpg
#   inflating: TrashBox_train_set/plastic/plastic 2557.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 2557.jpg
#   inflating: TrashBox_train_set/plastic/plastic 1738.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 1738.jpg
#   inflating: TrashBox_train_set/plastic/plastic 2231.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 2231.jpg
#   inflating: TrashBox_train_set/plastic/plastic 2225.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 2225.jpg
#   inflating: TrashBox_train_set/plastic/plastic 154.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 154.jpg
#   inflating: TrashBox_train_set/plastic/plastic 632.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 632.jpg
#   inflating: TrashBox_train_set/plastic/plastic 2543.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 2543.jpg
#   inflating: TrashBox_train_set/plastic/plastic 801.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 801.jpg
#   inflating: TrashBox_train_set/plastic/plastic 815.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 815.jpg
#   inflating: TrashBox_train_set/plastic/plastic 2594.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 2594.jpg
#   inflating: TrashBox_train_set/plastic/plastic 183.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 183.jpg
#   inflating: TrashBox_train_set/plastic/plastic 1923.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 1923.jpg
#   inflating: TrashBox_train_set/plastic/plastic 1937.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 1937.jpg
#   inflating: TrashBox_train_set/plastic/plastic 2580.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 2580.jpg
#   inflating: TrashBox_train_set/plastic/plastic 2379.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 2379.jpg
#   inflating: TrashBox_train_set/plastic/plastic 1670.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 1670.jpg
#   inflating: TrashBox_train_set/plastic/plastic 1102.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 1102.jpg
#   inflating: TrashBox_train_set/plastic/plastic 2423.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 2423.jpg
#   inflating: TrashBox_train_set/plastic/plastic 752.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 752.jpg
#   inflating: TrashBox_train_set/plastic/plastic 2345.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 2345.jpg
#   inflating: TrashBox_train_set/plastic/plastic 80.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 80.jpg
#   inflating: TrashBox_train_set/plastic/plastic 2351.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 2351.jpg
#   inflating: TrashBox_train_set/plastic/plastic 1880.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 1880.jpg
#   inflating: TrashBox_train_set/plastic/plastic 2437.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 2437.jpg
#   inflating: TrashBox_train_set/plastic/plastic 975.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 975.jpg
#   inflating: TrashBox_train_set/plastic/plastic 961.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 961.jpg
#   inflating: TrashBox_train_set/plastic/plastic 791.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 791.jpg
#   inflating: TrashBox_train_set/plastic/plastic 949.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 949.jpg
#   inflating: TrashBox_train_set/plastic/plastic 2386.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 2386.jpg
#   inflating: TrashBox_train_set/plastic/plastic 57.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 57.jpg
#   inflating: TrashBox_train_set/plastic/plastic 1857.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 1857.jpg
#   inflating: TrashBox_train_set/plastic/plastic 2392.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 2392.jpg
#   inflating: TrashBox_train_set/plastic/plastic 43.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 43.jpg
#   inflating: TrashBox_train_set/plastic/plastic 785.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 785.jpg
#   inflating: TrashBox_train_set/plastic/plastic 1472.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 1472.jpg
#   inflating: TrashBox_train_set/plastic/plastic 1314.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 1314.jpg
#   inflating: TrashBox_train_set/plastic/plastic 578.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 578.jpg
#   inflating: TrashBox_train_set/plastic/plastic 1466.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 1466.jpg
#   inflating: TrashBox_train_set/plastic/plastic 2147.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 2147.jpg
#   inflating: TrashBox_train_set/plastic/plastic 236.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 236.jpg
#   inflating: TrashBox_train_set/plastic/plastic 1328.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 1328.jpg
#   inflating: TrashBox_train_set/plastic/plastic 550.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 550.jpg
#   inflating: TrashBox_train_set/plastic/plastic 3.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 3.jpg
#   inflating: TrashBox_train_set/plastic/plastic 222.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 222.jpg
#   inflating: TrashBox_train_set/plastic/plastic 2184.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 2184.jpg
#   inflating: TrashBox_train_set/plastic/plastic 593.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 593.jpg
#   inflating: TrashBox_train_set/plastic/plastic 2190.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 2190.jpg
#   inflating: TrashBox_train_set/plastic/plastic 586.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 586.jpg
#   inflating: TrashBox_train_set/plastic/plastic 1498.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 1498.jpg
#   inflating: TrashBox_train_set/plastic/plastic 2191.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 2191.jpg
#   inflating: TrashBox_train_set/plastic/plastic 2185.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 2185.jpg
#   inflating: TrashBox_train_set/plastic/plastic 592.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 592.jpg
#   inflating: TrashBox_train_set/plastic/plastic 2634.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 2634.jpg
#   inflating: TrashBox_train_set/plastic/plastic 223.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 223.jpg
#   inflating: TrashBox_train_set/plastic/plastic 2.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 2.jpg
#   inflating: TrashBox_train_set/plastic/plastic 2152.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 2152.jpg
#   inflating: TrashBox_train_set/plastic/plastic 237.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 237.jpg
#   inflating: TrashBox_train_set/plastic/plastic 2146.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 2146.jpg
#   inflating: TrashBox_train_set/plastic/plastic 2620.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 2620.jpg
#   inflating: TrashBox_train_set/plastic/plastic 1329.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 1329.jpg
#   inflating: TrashBox_train_set/plastic/plastic 579.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 579.jpg
#   inflating: TrashBox_train_set/plastic/plastic 1301.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 1301.jpg
#   inflating: TrashBox_train_set/plastic/plastic 1467.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 1467.jpg
#   inflating: TrashBox_train_set/plastic/plastic 1315.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 1315.jpg
#   inflating: TrashBox_train_set/plastic/plastic 1842.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 1842.jpg
#   inflating: TrashBox_train_set/plastic/plastic 784.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 784.jpg
#   inflating: TrashBox_train_set/plastic/plastic 948.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 948.jpg
#   inflating: TrashBox_train_set/plastic/plastic 790.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 790.jpg
#   inflating: TrashBox_train_set/plastic/plastic 1856.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 1856.jpg
#   inflating: TrashBox_train_set/plastic/plastic 2387.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 2387.jpg
#   inflating: TrashBox_train_set/plastic/plastic 960.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 960.jpg
#   inflating: TrashBox_train_set/plastic/plastic 974.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 974.jpg
#   inflating: TrashBox_train_set/plastic/plastic 1881.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 1881.jpg
#   inflating: TrashBox_train_set/plastic/plastic 1659.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 1659.jpg
#   inflating: TrashBox_train_set/plastic/plastic 2350.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 2350.jpg
#   inflating: TrashBox_train_set/plastic/plastic 81.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 81.jpg
#   inflating: TrashBox_train_set/plastic/plastic 747.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 747.jpg
#   inflating: TrashBox_train_set/plastic/plastic 2436.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 2436.jpg
#   inflating: TrashBox_train_set/plastic/plastic 753.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 753.jpg
#   inflating: TrashBox_train_set/plastic/plastic 2422.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 2422.jpg
#   inflating: TrashBox_train_set/plastic/plastic 2344.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 2344.jpg
#   inflating: TrashBox_train_set/plastic/plastic 1895.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 1895.jpg
#   inflating: TrashBox_train_set/plastic/plastic 1665.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 1665.jpg
#   inflating: TrashBox_train_set/plastic/plastic 1103.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 1103.jpg
#   inflating: TrashBox_train_set/plastic/plastic 1117.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 1117.jpg
#   inflating: TrashBox_train_set/plastic/plastic 1671.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 1671.jpg
#   inflating: TrashBox_train_set/plastic/plastic 2378.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 2378.jpg
#   inflating: TrashBox_train_set/plastic/plastic 196.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 196.jpg
#   inflating: TrashBox_train_set/plastic/plastic 828.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 828.jpg
#   inflating: TrashBox_train_set/plastic/plastic 2595.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 2595.jpg
#   inflating: TrashBox_train_set/plastic/plastic 1922.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 1922.jpg
#   inflating: TrashBox_train_set/plastic/plastic 182.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 182.jpg
#   inflating: TrashBox_train_set/plastic/plastic 814.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 814.jpg
#   inflating: TrashBox_train_set/plastic/plastic 800.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 800.jpg
#   inflating: TrashBox_train_set/plastic/plastic 155.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 155.jpg
#   inflating: TrashBox_train_set/plastic/plastic 2542.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 2542.jpg
#   inflating: TrashBox_train_set/plastic/plastic 633.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 633.jpg
#   inflating: TrashBox_train_set/plastic/plastic 2556.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 2556.jpg
#   inflating: TrashBox_train_set/plastic/plastic 627.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 627.jpg
#   inflating: TrashBox_train_set/plastic/plastic 141.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 141.jpg
#   inflating: TrashBox_train_set/plastic/plastic 2230.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 2230.jpg
#   inflating: TrashBox_train_set/plastic/plastic 169.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 169.jpg
#   inflating: TrashBox_train_set/plastic/plastic 2218.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 2218.jpg
#   inflating: TrashBox_train_set/plastic/plastic 1077.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 1077.jpg
#   inflating: TrashBox_train_set/plastic/plastic 1249.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 1249.jpg
#   inflating: TrashBox_train_set/plastic/plastic 431.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 431.jpg
#   inflating: TrashBox_train_set/plastic/plastic 2026.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 2026.jpg
#   inflating: TrashBox_train_set/plastic/plastic 357.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 357.jpg
#   inflating: TrashBox_train_set/plastic/plastic 343.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 343.jpg
#   inflating: TrashBox_train_set/plastic/plastic 1275.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 1275.jpg
#   inflating: TrashBox_train_set/plastic/plastic 1513.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 1513.jpg
#   inflating: TrashBox_train_set/plastic/plastic 1507.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 1507.jpg
#   inflating: TrashBox_train_set/plastic/plastic 1261.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 1261.jpg
#   inflating: TrashBox_train_set/plastic/plastic 419.jpg
#   inflating: __MACOSX/TrashBox_train_set/plastic/._plastic 419.jpg

# %%
data_dir = "TrashBox_train_set"

# %%
transform = transforms.Compose([
      transforms.Resize((227,227)),
      transforms.ColorJitter(brightness=0.5, contrast=0.5, saturation=0, hue=0),
      transforms.RandomHorizontalFlip(0.3),
      transforms.RandomVerticalFlip(0.2),
      transforms.ToTensor(),
      transforms.Normalize(mean=[.5], std=[.5]),
      ])

# %%
dataset = ImageFolder(data_dir, transform = transform)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def show_sample(img, label):
    print("Label:", dataset.classes[label], "(Class No: "+ str(label) + ")")
    plt.imshow(img.permute(1, 2, 0))

img, label = dataset[10]
show_sample(img, label)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Label: cardboard (Class No: 0)

# %%
random_seed = 42
torch.manual_seed(random_seed)

# %%
train_ds, val_ds, test_ds = random_split(dataset, [7141, 4284, 2857])
len(train_ds), len(val_ds), len(test_ds)
# Out:
# (7141, 4284, 2857)

# %%
from torch.utils.data.dataloader import DataLoader
batch_size = 32
num_classes = 7

# %%
train_dl = DataLoader(train_ds, batch_size, shuffle = True, num_workers = 4, pin_memory = True)
val_dl = DataLoader(val_ds, batch_size*2, num_workers = 4, pin_memory = True)
test_dl = DataLoader(test_ds, batch_size*2, num_workers = 4, pin_memory = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
from torchvision.utils import make_grid

def show_batch(dl):
    for images, labels in dl:
        fig, ax = plt.subplots(figsize=(12, 6))
        ax.set_xticks([])
        ax.set_yticks([])
        ax.imshow(make_grid(images, nrow = 16).permute(1, 2, 0))
        break

# %%
show_batch(train_dl)
# Out:
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
def accuracy(outputs, labels):
    _, preds = torch.max(outputs, dim=1)
    return torch.tensor(torch.sum(preds == labels).item() / len(preds))

class ImageClassificationBase(nn.Module):
    def training_step(self, batch):
        images, labels = batch 
        out = self(images)                  # Generate predictions
        loss = F.cross_entropy(out, labels) # Calculate loss
        return loss
    
    def validation_step(self, batch):
        images, labels = batch 
        out = self(images)                    # Generate predictions
        loss = F.cross_entropy(out, labels)   # Calculate loss
        acc = accuracy(out, labels)           # Calculate accuracy
        return {'val_loss': loss.detach(), 'val_acc': acc}
        
    def validation_epoch_end(self, outputs):
        batch_losses = [x['val_loss'] for x in outputs]
        epoch_loss = torch.stack(batch_losses).mean()   # Combine losses
        batch_accs = [x['val_acc'] for x in outputs]
        epoch_acc = torch.stack(batch_accs).mean()      # Combine accuracies
        return {'val_loss': epoch_loss.item(), 'val_acc': epoch_acc.item()}
    
    def epoch_end(self, epoch, result):
        print("Epoch {}: train_loss: {:.4f}, val_loss: {:.4f}, val_acc: {:.4f}".format(
            epoch+1, result['train_loss'], result['val_loss'], result['val_acc']))

# %%
class AlexNet(nn.Module):
    def __init__(self, num_classes=10):
        super(AlexNet, self).__init__()
        self.layer1 = nn.Sequential(
            nn.Conv2d(3, 96, kernel_size=11, stride=4, padding=0),
            nn.BatchNorm2d(96),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size = 3, stride = 2))
        self.layer2 = nn.Sequential(
            nn.Conv2d(96, 256, kernel_size=5, stride=1, padding=2),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size = 3, stride = 2))
        self.layer3 = nn.Sequential(
            nn.Conv2d(256, 384, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(384),
            nn.ReLU())
        self.layer4 = nn.Sequential(
            nn.Conv2d(384, 384, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(384),
            nn.ReLU())
        self.layer5 = nn.Sequential(
            nn.Conv2d(384, 256, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size = 3, stride = 2))
        self.fc = nn.Sequential(
            nn.Dropout(0.5),
            nn.Linear(9216, 4096),
            nn.ReLU())
        self.fc1 = nn.Sequential(
            nn.Dropout(0.5),
            nn.Linear(4096, 4096),
            nn.ReLU())
        self.fc2= nn.Sequential(
            nn.Linear(4096, num_classes))
        
    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = self.layer5(out)
        out = out.reshape(out.size(0), -1)
        out = self.fc(out)
        out = self.fc1(out)
        out = self.fc2(out)
        return out

# %%
def get_default_device():
    """Pick GPU if available, else CPU"""
    if torch.cuda.is_available():
        return torch.device('cuda')
    else:
        return torch.device('cpu')
    
def to_device(data, device):
    """Move tensor(s) to chosen device"""
    if isinstance(data, (list,tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)

class DeviceDataLoader():
    """Wrap a dataloader to move data to a device"""
    def __init__(self, dl, device):
        self.dl = dl
        self.device = device
        
    def __iter__(self):
        """Yield a batch of data after moving it to device"""
        for b in self.dl: 
            yield to_device(b, self.device)

    def __len__(self):
        """Number of batches"""
        return len(self.dl)

# %%
device = get_default_device()
device
# Out:
# device(type='cuda')

# %%
train_dl = DeviceDataLoader(train_dl, device)
val_dl = DeviceDataLoader(val_dl, device)
model = AlexNet(7).to(device)
learning_rate = 0.005

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, weight_decay = 0.005, momentum = 0.9)

# %%
total_step = len(train_dl)
num_epochs = 5
history = []

for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_dl):  
        # Move tensors to the configured device
        images = images.to(device)
        labels = labels.to(device)
        
        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)
        
        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}' 
                   .format(epoch+1, num_epochs, i+1, total_step, loss.item()))
            
    # Validation
    with torch.no_grad():
        correct = 0
        total = 0
        for images, labels in val_dl:
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            del images, labels, outputs
        history.append(100 * correct / total)
        print('Accuracy of the network on the {} validation images: {} %'.format(5000, 100 * correct / total))
# Out:
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.7/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 11 bytes but only got 10. Skipping tag 42037
#   " Skipping tag %s" % (size, len(data), tag)
# Epoch [1/5], Step [224/224], Loss: 2.0769
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# Accuracy of the network on the 5000 validation images: 37.55835667600373 %
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.7/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 11 bytes but only got 10. Skipping tag 42037
#   " Skipping tag %s" % (size, len(data), tag)
# Epoch [2/5], Step [224/224], Loss: 1.3252
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# Accuracy of the network on the 5000 validation images: 38.93557422969187 %
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.7/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 11 bytes but only got 10. Skipping tag 42037
#   " Skipping tag %s" % (size, len(data), tag)
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# Epoch [3/5], Step [224/224], Loss: 2.1955
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# Accuracy of the network on the 5000 validation images: 38.63211951447246 %
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.7/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 11 bytes but only got 10. Skipping tag 42037
#   " Skipping tag %s" % (size, len(data), tag)
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# Epoch [4/5], Step [224/224], Loss: 1.5388
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# Accuracy of the network on the 5000 validation images: 40.26610644257703 %
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.7/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 11 bytes but only got 10. Skipping tag 42037
#   " Skipping tag %s" % (size, len(data), tag)
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# Epoch [5/5], Step [224/224], Loss: 1.8436
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# Accuracy of the network on the 5000 validation images: 42.48366013071895 %

# %%
def plot_accuracies(history):
    accuracies = [x for x in history]
    plt.plot(accuracies, '-x')
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.title('Accuracy vs. No. of epochs');

plot_accuracies(history)

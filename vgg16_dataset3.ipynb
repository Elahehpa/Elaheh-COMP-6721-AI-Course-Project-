# %%
#Importing Libraries
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import image
from matplotlib import pyplot
import time
import os
import torch
import torchvision
from torch.utils.data import random_split
import torchvision.models as models
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder

# %%
# !unzip "/content/drive/MyDrive/Dataset_3.zip"
# Out:
# Archive:  /content/drive/MyDrive/Dataset_3.zip
#    creating: trashify-image-dataset/
#   inflating: __MACOSX/._trashify-image-dataset
#    creating: trashify-image-dataset/paper/
#   inflating: __MACOSX/trashify-image-dataset/._paper
#    creating: trashify-image-dataset/metal/
#   inflating: __MACOSX/trashify-image-dataset/._metal
#    creating: trashify-image-dataset/plastic/
#   inflating: __MACOSX/trashify-image-dataset/._plastic
#   inflating: trashify-image-dataset/paper/IMG_20200416_215618.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._IMG_20200416_215618.jpg
#   inflating: trashify-image-dataset/paper/IMG_20200416_215142.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._IMG_20200416_215142.jpg
#   inflating: trashify-image-dataset/paper/20200416_213410.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_213410.jpg
#   inflating: trashify-image-dataset/paper/IMG_20200416_215234.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._IMG_20200416_215234.jpg
#   inflating: trashify-image-dataset/paper/IMG_20200416_215220.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._IMG_20200416_215220.jpg
#   inflating: trashify-image-dataset/paper/20200416_214752.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_214752.jpg
#   inflating: trashify-image-dataset/paper/IMG_20200416_214842.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._IMG_20200416_214842.jpg
#   inflating: trashify-image-dataset/paper/20200416_212041.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_212041.jpg
#   inflating: trashify-image-dataset/paper/20200416_214342.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_214342.jpg
#   inflating: trashify-image-dataset/paper/20200416_212645.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_212645.jpg
#   inflating: trashify-image-dataset/paper/20200416_213215.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_213215.jpg
#   inflating: trashify-image-dataset/paper/IMG_20200416_214854.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._IMG_20200416_214854.jpg
#   inflating: trashify-image-dataset/paper/20200416_211615.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_211615.jpg
#   inflating: trashify-image-dataset/paper/20200416_212254.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_212254.jpg
#   inflating: trashify-image-dataset/paper/IMG_20200416_214909.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._IMG_20200416_214909.jpg
#   inflating: trashify-image-dataset/paper/IMG_20200416_215150.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._IMG_20200416_215150.jpg
#   inflating: trashify-image-dataset/paper/20200416_214543.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_214543.jpg
#   inflating: trashify-image-dataset/paper/IMG_20200416_213643.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._IMG_20200416_213643.jpg
#   inflating: trashify-image-dataset/paper/20200416_214741.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_214741.jpg
#   inflating: trashify-image-dataset/paper/20200416_213601.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_213601.jpg
#   inflating: trashify-image-dataset/paper/20200416_214813.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_214813.jpg
#   inflating: trashify-image-dataset/paper/IMG_20200416_213536.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._IMG_20200416_213536.jpg
#   inflating: trashify-image-dataset/paper/20200416_214420.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_214420.jpg
#   inflating: trashify-image-dataset/paper/20200416_212051.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_212051.jpg
#   inflating: trashify-image-dataset/paper/20200416_211438.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_211438.jpg
#   inflating: trashify-image-dataset/paper/20200416_211809.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_211809.jpg
#   inflating: trashify-image-dataset/paper/20200416_213951.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_213951.jpg
#   inflating: trashify-image-dataset/paper/20200416_212508.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_212508.jpg
#   inflating: trashify-image-dataset/paper/20200416_214650.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_214650.jpg
#   inflating: trashify-image-dataset/paper/20200416_211700.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_211700.jpg
#   inflating: trashify-image-dataset/paper/20200416_213329.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_213329.jpg
#   inflating: trashify-image-dataset/paper/20200416_212433.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_212433.jpg
#   inflating: trashify-image-dataset/paper/20200416_211649.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_211649.jpg
#   inflating: trashify-image-dataset/paper/20200416_214916.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_214916.jpg
#   inflating: trashify-image-dataset/paper/20200416_212036.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_212036.jpg
#   inflating: trashify-image-dataset/paper/20200416_214848.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_214848.jpg
#   inflating: trashify-image-dataset/paper/20200416_212356.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_212356.jpg
#   inflating: trashify-image-dataset/paper/20200416_212424.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_212424.jpg
#   inflating: trashify-image-dataset/paper/IMG_20200416_214413.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._IMG_20200416_214413.jpg
#   inflating: trashify-image-dataset/paper/20200416_212948.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_212948.jpg
#   inflating: trashify-image-dataset/paper/IMG_20200416_215133.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._IMG_20200416_215133.jpg
#   inflating: trashify-image-dataset/paper/20200416_213313.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_213313.jpg
#   inflating: trashify-image-dataset/paper/20200416_212031.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_212031.jpg
#   inflating: trashify-image-dataset/paper/20200416_213059.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_213059.jpg
#   inflating: trashify-image-dataset/paper/20200416_212805.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_212805.jpg
#   inflating: trashify-image-dataset/paper/20200416_214441.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_214441.jpg
#   inflating: trashify-image-dataset/paper/20200416_212959.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_212959.jpg
#   inflating: trashify-image-dataset/paper/IMG_20200416_215318.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._IMG_20200416_215318.jpg
#   inflating: trashify-image-dataset/paper/IMG_20200416_215050.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._IMG_20200416_215050.jpg
#   inflating: trashify-image-dataset/paper/20200416_212351.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_212351.jpg
#   inflating: trashify-image-dataset/paper/IMG_20200416_215247.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._IMG_20200416_215247.jpg
#   inflating: trashify-image-dataset/paper/20200416_214654.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_214654.jpg
#   inflating: trashify-image-dataset/paper/IMG_20200416_215455.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._IMG_20200416_215455.jpg
#   inflating: trashify-image-dataset/paper/IMG_20200416_215327.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._IMG_20200416_215327.jpg
#   inflating: trashify-image-dataset/paper/20200416_213852.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_213852.jpg
#   inflating: trashify-image-dataset/paper/IMG_20200416_214550.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._IMG_20200416_214550.jpg
#   inflating: trashify-image-dataset/paper/20200416_214513.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_214513.jpg
#   inflating: trashify-image-dataset/paper/20200416_214937.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_214937.jpg
#   inflating: trashify-image-dataset/paper/20200416_212611.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_212611.jpg
#   inflating: trashify-image-dataset/paper/20200416_211536.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_211536.jpg
#   inflating: trashify-image-dataset/paper/IMG_20200416_215101.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._IMG_20200416_215101.jpg
#   inflating: trashify-image-dataset/paper/IMG_20200416_214753.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._IMG_20200416_214753.jpg
#   inflating: trashify-image-dataset/paper/IMG_20200416_214948.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._IMG_20200416_214948.jpg
#   inflating: trashify-image-dataset/paper/IMG_20200416_213348.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._IMG_20200416_213348.jpg
#   inflating: trashify-image-dataset/paper/IMG_20200416_215513.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._IMG_20200416_215513.jpg
#   inflating: trashify-image-dataset/paper/20200416_211657.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_211657.jpg
#   inflating: trashify-image-dataset/paper/20200416_214505.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_214505.jpg
#   inflating: trashify-image-dataset/paper/20200416_213444.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_213444.jpg
#   inflating: trashify-image-dataset/paper/20200416_215035.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_215035.jpg
#   inflating: trashify-image-dataset/paper/20200416_214840.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_214840.jpg
#   inflating: trashify-image-dataset/paper/IMG_20200416_215112.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._IMG_20200416_215112.jpg
#   inflating: trashify-image-dataset/paper/20200416_215025.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_215025.jpg
#   inflating: trashify-image-dataset/paper/20200416_212428.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_212428.jpg
#   inflating: trashify-image-dataset/paper/IMG_20200416_213601.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._IMG_20200416_213601.jpg
#   inflating: trashify-image-dataset/paper/20200416_214703.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_214703.jpg
#   inflating: trashify-image-dataset/paper/IMG_20200416_213628.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._IMG_20200416_213628.jpg
#   inflating: trashify-image-dataset/paper/IMG_20200416_215503.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._IMG_20200416_215503.jpg
#   inflating: trashify-image-dataset/paper/IMG_20200416_214741.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._IMG_20200416_214741.jpg
#   inflating: trashify-image-dataset/paper/20200416_213119.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_213119.jpg
#   inflating: trashify-image-dataset/paper/IMG_20200416_214541.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._IMG_20200416_214541.jpg
#   inflating: trashify-image-dataset/paper/IMG_20200416_214435.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._IMG_20200416_214435.jpg
#   inflating: trashify-image-dataset/paper/20200416_213046.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_213046.jpg
#   inflating: trashify-image-dataset/paper/IMG_20200416_213429.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._IMG_20200416_213429.jpg
#   inflating: trashify-image-dataset/paper/20200416_213126.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_213126.jpg
#   inflating: trashify-image-dataset/paper/IMG_20200416_214959.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._IMG_20200416_214959.jpg
#   inflating: trashify-image-dataset/paper/IMG_20200416_214719.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._IMG_20200416_214719.jpg
#   inflating: trashify-image-dataset/paper/20200416_211434.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_211434.jpg
#   inflating: trashify-image-dataset/paper/20200416_213035.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_213035.jpg
#   inflating: trashify-image-dataset/paper/20200416_211623.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_211623.jpg
#   inflating: trashify-image-dataset/paper/20200416_211541.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_211541.jpg
#   inflating: trashify-image-dataset/paper/20200416_213356.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_213356.jpg
#   inflating: trashify-image-dataset/paper/IMG_20200416_214532.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._IMG_20200416_214532.jpg
#   inflating: trashify-image-dataset/paper/20200416_211741.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_211741.jpg
#   inflating: trashify-image-dataset/paper/20200416_214413.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_214413.jpg
#   inflating: trashify-image-dataset/paper/20200416_212102.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_212102.jpg
#   inflating: trashify-image-dataset/paper/20200416_212301.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_212301.jpg
#   inflating: trashify-image-dataset/paper/20200416_211422.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_211422.jpg
#   inflating: trashify-image-dataset/paper/IMG_20200416_214451.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._IMG_20200416_214451.jpg
#   inflating: trashify-image-dataset/paper/IMG_20200416_213510.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._IMG_20200416_213510.jpg
#   inflating: trashify-image-dataset/paper/20200416_214348.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_214348.jpg
#   inflating: trashify-image-dataset/paper/20200416_214604.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_214604.jpg
#   inflating: trashify-image-dataset/paper/20200416_214823.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_214823.jpg
#   inflating: trashify-image-dataset/paper/20200416_213816.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_213816.jpg
#   inflating: trashify-image-dataset/paper/20200416_212259.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_212259.jpg
#   inflating: trashify-image-dataset/paper/20200416_211803.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_211803.jpg
#   inflating: trashify-image-dataset/paper/IMG_20200416_214939.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._IMG_20200416_214939.jpg
#   inflating: trashify-image-dataset/paper/IMG_20200416_211855.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._IMG_20200416_211855.jpg
#   inflating: trashify-image-dataset/paper/20200416_211948.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_211948.jpg
#   inflating: trashify-image-dataset/paper/20200416_211747.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_211747.jpg
#   inflating: trashify-image-dataset/paper/20200416_212528.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_212528.jpg
#   inflating: trashify-image-dataset/paper/20200416_213144.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_213144.jpg
#   inflating: trashify-image-dataset/paper/IMG_20200416_213517.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._IMG_20200416_213517.jpg
#   inflating: trashify-image-dataset/paper/20200416_214429.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_214429.jpg
#   inflating: trashify-image-dataset/paper/20200416_212058.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_212058.jpg
#   inflating: trashify-image-dataset/paper/20200416_212448.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_212448.jpg
#   inflating: trashify-image-dataset/paper/20200416_213019.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_213019.jpg
#   inflating: trashify-image-dataset/paper/20200416_211626.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_211626.jpg
#   inflating: trashify-image-dataset/paper/20200416_213025.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_213025.jpg
#   inflating: trashify-image-dataset/paper/20200416_214945.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_214945.jpg
#   inflating: trashify-image-dataset/paper/20200416_213151.jpg
#   inflating: __MACOSX/trashify-image-dataset/paper/._20200416_213151.jpg
#   inflating: trashify-image-dataset/metal/20200331_115128.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._20200331_115128.jpg
#   inflating: trashify-image-dataset/metal/68649.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68649.jpg
#   inflating: trashify-image-dataset/metal/20200331_113820.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._20200331_113820.jpg
#   inflating: trashify-image-dataset/metal/20200331_114829.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._20200331_114829.jpg
#   inflating: trashify-image-dataset/metal/68648.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68648.jpg
#   inflating: trashify-image-dataset/metal/20200331_114419.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._20200331_114419.jpg
#   inflating: trashify-image-dataset/metal/20200331_232935.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._20200331_232935.jpg
#   inflating: trashify-image-dataset/metal/20200331_114624.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._20200331_114624.jpg
#   inflating: trashify-image-dataset/metal/20200331_113611.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._20200331_113611.jpg
#   inflating: trashify-image-dataset/metal/20200331_114032.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._20200331_114032.jpg
#   inflating: trashify-image-dataset/metal/20200331_114351.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._20200331_114351.jpg
#   inflating: trashify-image-dataset/metal/20200331_113010.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._20200331_113010.jpg
#   inflating: trashify-image-dataset/metal/20200331_113428.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._20200331_113428.jpg
#   inflating: trashify-image-dataset/metal/20200331_113825.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._20200331_113825.jpg
#   inflating: trashify-image-dataset/metal/20200331_114804.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._20200331_114804.jpg
#   inflating: trashify-image-dataset/metal/20200331_114811.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._20200331_114811.jpg
#   inflating: trashify-image-dataset/metal/68616.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68616.jpg
#   inflating: trashify-image-dataset/metal/68602.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68602.jpg
#   inflating: trashify-image-dataset/metal/68603.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68603.jpg
#   inflating: trashify-image-dataset/metal/68617.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68617.jpg
#   inflating: trashify-image-dataset/metal/68588.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68588.jpg
#   inflating: trashify-image-dataset/metal/20200331_113707.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._20200331_113707.jpg
#   inflating: trashify-image-dataset/metal/20200331_112828.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._20200331_112828.jpg
#   inflating: trashify-image-dataset/metal/68629.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68629.jpg
#   inflating: trashify-image-dataset/metal/68601.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68601.jpg
#   inflating: trashify-image-dataset/metal/68615.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68615.jpg
#   inflating: trashify-image-dataset/metal/20200331_113129.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._20200331_113129.jpg
#   inflating: trashify-image-dataset/metal/68614.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68614.jpg
#   inflating: trashify-image-dataset/metal/68600.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68600.jpg
#   inflating: trashify-image-dataset/metal/68628.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68628.jpg
#   inflating: trashify-image-dataset/metal/68589.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68589.jpg
#   inflating: trashify-image-dataset/metal/68599.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68599.jpg
#   inflating: trashify-image-dataset/metal/20200331_113716.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._20200331_113716.jpg
#   inflating: trashify-image-dataset/metal/68604.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68604.jpg
#   inflating: trashify-image-dataset/metal/68610.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68610.jpg
#   inflating: trashify-image-dataset/metal/68638.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68638.jpg
#   inflating: trashify-image-dataset/metal/68639.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68639.jpg
#   inflating: trashify-image-dataset/metal/68611.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68611.jpg
#   inflating: trashify-image-dataset/metal/68605.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68605.jpg
#   inflating: trashify-image-dataset/metal/68598.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68598.jpg
#   inflating: trashify-image-dataset/metal/20200331_114044.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._20200331_114044.jpg
#   inflating: trashify-image-dataset/metal/20200331_113701.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._20200331_113701.jpg
#   inflating: trashify-image-dataset/metal/68613.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68613.jpg
#   inflating: trashify-image-dataset/metal/68607.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68607.jpg
#   inflating: trashify-image-dataset/metal/20200331_113853.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._20200331_113853.jpg
#   inflating: trashify-image-dataset/metal/68606.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68606.jpg
#   inflating: trashify-image-dataset/metal/68612.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68612.jpg
#   inflating: trashify-image-dataset/metal/20200331_113043.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._20200331_113043.jpg
#   inflating: trashify-image-dataset/metal/68582.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68582.jpg
#   inflating: trashify-image-dataset/metal/68596.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68596.jpg
#   inflating: trashify-image-dataset/metal/68637.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68637.jpg
#   inflating: trashify-image-dataset/metal/68623.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68623.jpg
#   inflating: trashify-image-dataset/metal/68622.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68622.jpg
#   inflating: trashify-image-dataset/metal/68636.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68636.jpg
#   inflating: trashify-image-dataset/metal/20200331_112837.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._20200331_112837.jpg
#   inflating: trashify-image-dataset/metal/68597.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68597.jpg
#   inflating: trashify-image-dataset/metal/68583.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68583.jpg
#   inflating: trashify-image-dataset/metal/20200331_113724.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._20200331_113724.jpg
#   inflating: trashify-image-dataset/metal/20200331_113042.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._20200331_113042.jpg
#   inflating: trashify-image-dataset/metal/68595.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68595.jpg
#   inflating: trashify-image-dataset/metal/68581.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68581.jpg
#   inflating: trashify-image-dataset/metal/68608.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68608.jpg
#   inflating: trashify-image-dataset/metal/68620.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68620.jpg
#   inflating: trashify-image-dataset/metal/68634.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68634.jpg
#   inflating: trashify-image-dataset/metal/68635.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68635.jpg
#   inflating: trashify-image-dataset/metal/68621.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68621.jpg
#   inflating: trashify-image-dataset/metal/68609.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68609.jpg
#   inflating: trashify-image-dataset/metal/20200331_112940.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._20200331_112940.jpg
#   inflating: trashify-image-dataset/metal/20200331_113914.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._20200331_113914.jpg
#   inflating: trashify-image-dataset/metal/68580.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68580.jpg
#   inflating: trashify-image-dataset/metal/68594.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68594.jpg
#   inflating: trashify-image-dataset/metal/68590.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68590.jpg
#   inflating: trashify-image-dataset/metal/68584.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68584.jpg
#   inflating: trashify-image-dataset/metal/20200331_113910.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._20200331_113910.jpg
#   inflating: trashify-image-dataset/metal/68625.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68625.jpg
#   inflating: trashify-image-dataset/metal/68631.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68631.jpg
#   inflating: trashify-image-dataset/metal/68619.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68619.jpg
#   inflating: trashify-image-dataset/metal/20200331_112944.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._20200331_112944.jpg
#   inflating: trashify-image-dataset/metal/20200331_113131.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._20200331_113131.jpg
#   inflating: trashify-image-dataset/metal/68618.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68618.jpg
#   inflating: trashify-image-dataset/metal/68630.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68630.jpg
#   inflating: trashify-image-dataset/metal/68624.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68624.jpg
#   inflating: trashify-image-dataset/metal/68585.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68585.jpg
#   inflating: trashify-image-dataset/metal/68591.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68591.jpg
#   inflating: trashify-image-dataset/metal/68587.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68587.jpg
#   inflating: trashify-image-dataset/metal/68593.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68593.jpg
#   inflating: trashify-image-dataset/metal/20200331_113720.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._20200331_113720.jpg
#   inflating: trashify-image-dataset/metal/68632.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68632.jpg
#   inflating: trashify-image-dataset/metal/68626.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68626.jpg
#   inflating: trashify-image-dataset/metal/68627.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68627.jpg
#   inflating: trashify-image-dataset/metal/68633.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68633.jpg
#   inflating: trashify-image-dataset/metal/68592.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68592.jpg
#   inflating: trashify-image-dataset/metal/68586.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68586.jpg
#   inflating: trashify-image-dataset/metal/68640.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68640.jpg
#   inflating: trashify-image-dataset/metal/20200331_113633.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._20200331_113633.jpg
#   inflating: trashify-image-dataset/metal/68641.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68641.jpg
#   inflating: trashify-image-dataset/metal/20200331_112840.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._20200331_112840.jpg
#   inflating: trashify-image-dataset/metal/20200331_114014.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._20200331_114014.jpg
#   inflating: trashify-image-dataset/metal/20200331_113747.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._20200331_113747.jpg
#   inflating: trashify-image-dataset/metal/20200331_113023.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._20200331_113023.jpg
#   inflating: trashify-image-dataset/metal/20200331_113751.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._20200331_113751.jpg
#   inflating: trashify-image-dataset/metal/68643.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68643.jpg
#   inflating: trashify-image-dataset/metal/20200331_114837.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._20200331_114837.jpg
#   inflating: trashify-image-dataset/metal/68642.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68642.jpg
#   inflating: trashify-image-dataset/metal/20200331_115133.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._20200331_115133.jpg
#   inflating: trashify-image-dataset/metal/68646.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68646.jpg
#   inflating: trashify-image-dataset/metal/20200331_113620.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._20200331_113620.jpg
#   inflating: trashify-image-dataset/metal/20200331_114833.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._20200331_114833.jpg
#   inflating: trashify-image-dataset/metal/68647.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68647.jpg
#   inflating: trashify-image-dataset/metal/20200331_114358.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._20200331_114358.jpg
#   inflating: trashify-image-dataset/metal/20200331_113019.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._20200331_113019.jpg
#   inflating: trashify-image-dataset/metal/20200331_115118.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._20200331_115118.jpg
#   inflating: trashify-image-dataset/metal/20200331_115124.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._20200331_115124.jpg
#   inflating: trashify-image-dataset/metal/20200331_114414.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._20200331_114414.jpg
#   inflating: trashify-image-dataset/metal/68645.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68645.jpg
#   inflating: trashify-image-dataset/metal/20200331_113810.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._20200331_113810.jpg
#   inflating: trashify-image-dataset/metal/20200331_113805.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._20200331_113805.jpg
#   inflating: trashify-image-dataset/metal/68644.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._68644.jpg
#   inflating: trashify-image-dataset/metal/20200331_113420.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._20200331_113420.jpg
#   inflating: trashify-image-dataset/metal/20200331_114039.jpg
#   inflating: __MACOSX/trashify-image-dataset/metal/._20200331_114039.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_120601.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_120601.jpg
#   inflating: trashify-image-dataset/plastic/304561.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._304561.jpg
#   inflating: trashify-image-dataset/plastic/304575.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._304575.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_114349.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_114349.jpg
#   inflating: trashify-image-dataset/plastic/304549.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._304549.jpg
#   inflating: trashify-image-dataset/plastic/304548.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._304548.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_113341.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_113341.jpg
#   inflating: trashify-image-dataset/plastic/304574.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._304574.jpg
#   inflating: trashify-image-dataset/plastic/304560.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._304560.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_115136.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_115136.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_112659.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_112659.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_115450.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_115450.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_114404.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_114404.jpg
#   inflating: trashify-image-dataset/plastic/304576.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._304576.jpg
#   inflating: trashify-image-dataset/plastic/304562.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._304562.jpg
#   inflating: trashify-image-dataset/plastic/304563.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._304563.jpg
#   inflating: trashify-image-dataset/plastic/304577.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._304577.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_115914.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_115914.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_115323.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_115323.jpg
#   inflating: trashify-image-dataset/plastic/304573.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._304573.jpg
#   inflating: trashify-image-dataset/plastic/304567.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._304567.jpg
#   inflating: trashify-image-dataset/plastic/304566.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._304566.jpg
#   inflating: trashify-image-dataset/plastic/304572.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._304572.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_115124.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_115124.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_112852.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_112852.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_113033.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_113033.jpg
#   inflating: trashify-image-dataset/plastic/304558.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._304558.jpg
#   inflating: trashify-image-dataset/plastic/304564.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._304564.jpg
#   inflating: trashify-image-dataset/plastic/304570.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._304570.jpg
#   inflating: trashify-image-dataset/plastic/304571.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._304571.jpg
#   inflating: trashify-image-dataset/plastic/304565.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._304565.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_112728.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_112728.jpg
#   inflating: trashify-image-dataset/plastic/304559.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._304559.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_114629.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_114629.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_113542.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_113542.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_113556.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_113556.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_115641.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_115641.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_112820.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_112820.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_115154.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_115154.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_115222.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_115222.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_113323.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_113323.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_113518.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_113518.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_114513.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_114513.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_115433.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_115433.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_114659.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_114659.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_112002.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_112002.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_114314.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_114314.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_115234.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_115234.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_113057.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_113057.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_112601.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_112601.jpg
#   inflating: trashify-image-dataset/plastic/304538.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._304538.jpg
#   inflating: trashify-image-dataset/plastic/304539.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._304539.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_120329.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_120329.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_120101.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_120101.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_114055.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_114055.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_113712.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_113712.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_115954.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_115954.jpg
#   inflating: trashify-image-dataset/plastic/304537.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._304537.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_113303.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_113303.jpg
#   inflating: trashify-image-dataset/plastic/304536.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._304536.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_112948.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_112948.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_115404.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_115404.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_120118.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_120118.jpg
#   inflating: trashify-image-dataset/plastic/304534.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._304534.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_114452.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_114452.jpg
#   inflating: trashify-image-dataset/plastic/304535.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._304535.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_120245.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_120245.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_114043.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_114043.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_112432.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_112432.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_120443.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_120443.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_115601.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_115601.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_114127.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_114127.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_115628.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_115628.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_112145.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_112145.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_115212.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_115212.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_112757.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_112757.jpg
#   inflating: trashify-image-dataset/plastic/304532.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._304532.jpg
#   inflating: trashify-image-dataset/plastic/304533.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._304533.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_120041.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_120041.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_112352.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_112352.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_114723.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_114723.jpg
#   inflating: trashify-image-dataset/plastic/304540.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._304540.jpg
#   inflating: trashify-image-dataset/plastic/304554.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._304554.jpg
#   inflating: trashify-image-dataset/plastic/304568.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._304568.jpg
#   inflating: trashify-image-dataset/plastic/304569.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._304569.jpg
#   inflating: trashify-image-dataset/plastic/304555.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._304555.jpg
#   inflating: trashify-image-dataset/plastic/304541.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._304541.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_120219.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_120219.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_114751.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_114751.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_113228.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_113228.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_112524.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_112524.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_115511.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_115511.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_120025.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_120025.jpg
#   inflating: trashify-image-dataset/plastic/304580.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._304580.jpg
#   inflating: trashify-image-dataset/plastic/304557.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._304557.jpg
#   inflating: trashify-image-dataset/plastic/304543.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._304543.jpg
#   inflating: trashify-image-dataset/plastic/304542.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._304542.jpg
#   inflating: trashify-image-dataset/plastic/304556.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._304556.jpg
#   inflating: trashify-image-dataset/plastic/304581.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._304581.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_120540.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_120540.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_120352.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_120352.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_112455.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_112455.jpg
#   inflating: trashify-image-dataset/plastic/304552.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._304552.jpg
#   inflating: trashify-image-dataset/plastic/304546.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._304546.jpg
#   inflating: trashify-image-dataset/plastic/304547.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._304547.jpg
#   inflating: trashify-image-dataset/plastic/304553.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._304553.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_120551.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_120551.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_115311.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_115311.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_113628.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_113628.jpg
#   inflating: trashify-image-dataset/plastic/304579.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._304579.jpg
#   inflating: trashify-image-dataset/plastic/304545.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._304545.jpg
#   inflating: trashify-image-dataset/plastic/304551.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._304551.jpg
#   inflating: trashify-image-dataset/plastic/304550.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._304550.jpg
#   inflating: trashify-image-dataset/plastic/304544.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._304544.jpg
#   inflating: trashify-image-dataset/plastic/304578.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._304578.jpg
#   inflating: trashify-image-dataset/plastic/IMG_20200415_120426.jpg
#   inflating: __MACOSX/trashify-image-dataset/plastic/._IMG_20200415_120426.jpg

# %%
data_dir = "trashify-image-dataset"

# %%
transform = transforms.Compose([
      transforms.Resize((227,227)),
      transforms.ColorJitter(brightness=0.5, contrast=0.5, saturation=0, hue=0),
      transforms.RandomHorizontalFlip(0.3),
      transforms.RandomVerticalFlip(0.2),
      transforms.ToTensor(),
      transforms.Normalize(mean=[.5], std=[.5]),
      ])

# %%
dataset = ImageFolder(data_dir, transform = transform)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def show_sample(img, label):
    print("Label:", dataset.classes[label], "(Class No: "+ str(label) + ")")
    plt.imshow(img.permute(1, 2, 0))

img, label = dataset[10]
show_sample(img, label)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Label: metal (Class No: 0)

# %%
random_seed = 42
torch.manual_seed(random_seed)

# %%
train_size = int(0.7 * len(dataset))
val_size = int(0.15 * len(dataset))
test_size = len(dataset) - train_size - val_size
train_ds, val_ds, test_ds = random_split(dataset, [train_size, val_size, test_size])
len(train_ds), len(val_ds), len(test_ds)
# Out:
# (249, 53, 54)

# %%
from torch.utils.data.dataloader import DataLoader
batch_size = 32
num_classes = 7

# %%
train_dl = DataLoader(train_ds, batch_size, shuffle = True, num_workers = 4, pin_memory = True)
val_dl = DataLoader(val_ds, batch_size*2, num_workers = 4, pin_memory = True)
test_dl = DataLoader(test_ds, batch_size*2, num_workers = 4, pin_memory = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
from torchvision.utils import make_grid

def show_batch(dl):
    for images, labels in dl:
        fig, ax = plt.subplots(figsize=(12, 6))
        ax.set_xticks([])
        ax.set_yticks([])
        ax.imshow(make_grid(images, nrow = 16).permute(1, 2, 0))
        break

# %%
show_batch(train_dl)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
def accuracy(outputs, labels):
    _, preds = torch.max(outputs, dim=1)
    return torch.tensor(torch.sum(preds == labels).item() / len(preds))

class ImageClassificationBase(nn.Module):
    def training_step(self, batch):
        images, labels = batch 
        out = self(images)                  # Generate predictions
        loss = F.cross_entropy(out, labels) # Calculate loss
        acc = accuracy(out, labels)           # Calculate accuracy
        return {'train_loss': loss.detach(), 'train_acc': acc}

    def testing_step(self, batch):
        images, labels = batch 
        out = self(images)                  # Generate predictions
        loss = F.cross_entropy(out, labels) # Calculate loss
        acc = accuracy(out, labels)           # Calculate accuracy
        return {'test_loss': loss.detach(), 'test_acc': acc}
    
    def validation_step(self, batch):
        images, labels = batch 
        out = self(images)                    # Generate predictions
        loss = F.cross_entropy(out, labels)   # Calculate loss
        acc = accuracy(out, labels)           # Calculate accuracy
        return {'val_loss': loss.detach(), 'val_acc': acc}

    def training_epoch_end(self, outputs):
        batch_losses = [x['train_loss'] for x in outputs]
        epoch_loss = torch.stack(batch_losses).mean()   # Combine losses
        batch_accs = [x['train_acc'] for x in outputs]
        epoch_acc = torch.stack(batch_accs).mean()      # Combine accuracies
        return {'train_loss': epoch_loss.item(), 'train_acc': epoch_acc.item()}
       
    def testing_epoch_end(self, outputs):
        batch_losses = [x['test_loss'] for x in outputs]
        epoch_loss = torch.stack(batch_losses).mean()   # Combine losses
        batch_accs = [x['test_acc'] for x in outputs]
        epoch_acc = torch.stack(batch_accs).mean()      # Combine accuracies
        return {'test_loss': epoch_loss.item(), 'test_acc': epoch_acc.item()}
       
    def validation_epoch_end(self, outputs):
        batch_losses = [x['val_loss'] for x in outputs]
        epoch_loss = torch.stack(batch_losses).mean()   # Combine losses
        batch_accs = [x['val_acc'] for x in outputs]
        epoch_acc = torch.stack(batch_accs).mean()      # Combine accuracies
        return {'val_loss': epoch_loss.item(), 'val_acc': epoch_acc.item()}
    
    def epoch_end(self, epoch, result):
        print("Epoch {}: train_loss: {:.4f}, test_loss: {:.4f}, val_loss: {:.4f}, train_acc: {:.4f}, test_acc: {:.4f}, val_acc: {:.4f}".format(
            epoch+1, result['train_loss'], result['test_loss'], result['val_loss'], result['train_acc'], result['test_acc'], result['val_acc']))

# %%
model = models.vgg16()
num_ftrs = model.classifier[0].in_features
model.fc = nn.Linear(num_ftrs, 2)

# %%
def get_default_device():
    """Pick GPU if available, else CPU"""
    if torch.cuda.is_available():
        return torch.device('cuda')
    else:
        return torch.device('cpu')
    
def to_device(data, device):
    """Move tensor(s) to chosen device"""
    if isinstance(data, (list,tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)

class DeviceDataLoader():
    """Wrap a dataloader to move data to a device"""
    def __init__(self, dl, device):
        self.dl = dl
        self.device = device
        
    def __iter__(self):
        """Yield a batch of data after moving it to device"""
        for b in self.dl: 
            yield to_device(b, self.device)

    def __len__(self):
        """Number of batches"""
        return len(self.dl)

# %%
device = get_default_device()
device
# Out:
# device(type='cuda')

# %%
train_dl = DeviceDataLoader(train_dl, device)
test_dl = DeviceDataLoader(test_dl, device)
val_dl = DeviceDataLoader(val_dl, device)
to_device(model, device)
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
#   (fc): Linear(in_features=25088, out_features=2, bias=True)
# )

# %%
from torch.nn.modules import loss
from torch.optim.adam import Adam
num_epochs = 8
lr = 0.0001
optimizer = Adam(model.parameters(), lr=lr)
loss_function = nn.CrossEntropyLoss();

# %%
from torch.autograd import Variable
#Model Training and saving best Model
best_accuracy = 0.0
train_acc_list = []
test_acc_list = []
val_acc_list = []
train_loss_list = []
test_loss_list = []
val_loss_list = []
epo = []
for epoch in range(num_epochs):
  #evaluation and training on training dataset
  model.train()
  train_acc = 0.0
  train_loss = 0.0

  for i, (images, labels) in enumerate(train_dl):
    if(torch.cuda.is_available()):
      images = Variable(images.cuda())
      labels = Variable(labels.cuda())
      
    optimizer.zero_grad()
    outputs = model(images)
    loss = loss_function(outputs, labels)
    loss.backward()
    optimizer.step()

    train_loss += loss.cpu().data*images.size(0)
    _,prediction=torch.max(outputs.data,1)

    train_acc += int(torch.sum(prediction==labels.data))

  train_acc = train_acc / train_size
  train_loss = train_loss / train_size
      
  #Evaluation on testing dataset
  model.eval()

  test_acc = 0.0
  correct1 = 0
  total1 = 0
  test_loss = 0.0

  for i, (images, labels) in enumerate(test_dl):
    if(torch.cuda.is_available()):
      images = Variable(images.cuda())
      labels = Variable(labels.cuda())

    outputs = model(images)
    test_loss += loss.cpu().data*images.size(0)
    _,prediction=torch.max(outputs.data,1)
    test_acc += int(torch.sum(prediction==labels.data))
    total1 += labels.size(0)
    correct1 += (prediction == labels).sum().item()
  
  test_acc = test_acc / test_size
  test_loss = test_loss / test_size

  val_acc = 0.0
  correct2 = 0
  total2 = 0
  val_loss = 0.0

  for i, (images, labels) in enumerate(val_dl):
    if(torch.cuda.is_available()):
      images = Variable(images.cuda())
      labels = Variable(labels.cuda())

    outputs = model(images)
    val_loss += loss.cpu().data*images.size(0)
    _,prediction=torch.max(outputs.data,1)
    val_acc += int(torch.sum(prediction==labels.data))
    total2 += labels.size(0)
    correct2 += (prediction == labels).sum().item()

  val_loss = val_loss / val_size
  val_acc = val_acc / val_size
  print('Epoch: '+str(epoch+1)+' Train Loss: '+str(train_loss)+ ' Train Accuracy: '+str(train_acc) + 
                              ' Test Accuracy: '+str(test_acc) + 
                               ' Validation Loss: '+str(val_loss)+ ' Validation Accuracy: '+str(val_acc))
  train_acc_list.append(train_acc)
  test_acc_list.append(test_acc)
  val_acc_list.append(val_acc)
  train_loss_list.append(train_loss)
  test_loss_list.append(test_loss)
  val_loss_list.append(val_loss)
  epo.append(epoch+1)

  if(test_acc>best_accuracy):
    torch.save(model.state_dict(), 'best_checkpoint.model')
    best_accuracy = test_acc
print('Test Accuracy of the model on the {} test images: {} %'.format(total1, (correct1 / total1) * 100))
print('Test Accuracy of the model on the {} validation images: {} %'.format(total2, (correct2 / total2) * 100))
# Out:
# Epoch: 1 Train Loss: tensor(3.5819) Train Accuracy: 0.43373493975903615 Test Accuracy: 0.5370370370370371 Validation Loss: tensor(3.0070) Validation Accuracy: 0.5283018867924528
# Epoch: 2 Train Loss: tensor(1.1070) Train Accuracy: 0.6305220883534136 Test Accuracy: 0.42592592592592593 Validation Loss: tensor(0.8989) Validation Accuracy: 0.6037735849056604
# Epoch: 3 Train Loss: tensor(0.5597) Train Accuracy: 0.7670682730923695 Test Accuracy: 0.7962962962962963 Validation Loss: tensor(0.4829) Validation Accuracy: 0.8867924528301887
# Epoch: 4 Train Loss: tensor(0.2587) Train Accuracy: 0.891566265060241 Test Accuracy: 0.8333333333333334 Validation Loss: tensor(0.3740) Validation Accuracy: 0.8867924528301887
# Epoch: 5 Train Loss: tensor(0.1280) Train Accuracy: 0.963855421686747 Test Accuracy: 0.9259259259259259 Validation Loss: tensor(0.2031) Validation Accuracy: 0.9622641509433962
# Epoch: 6 Train Loss: tensor(0.1377) Train Accuracy: 0.9558232931726908 Test Accuracy: 0.8703703703703703 Validation Loss: tensor(0.4497) Validation Accuracy: 0.9433962264150944
# Epoch: 7 Train Loss: tensor(0.0767) Train Accuracy: 0.9759036144578314 Test Accuracy: 0.9259259259259259 Validation Loss: tensor(0.0809) Validation Accuracy: 0.9245283018867925
# Epoch: 8 Train Loss: tensor(0.0552) Train Accuracy: 0.9879518072289156 Test Accuracy: 0.9074074074074074 Validation Loss: tensor(0.2446) Validation Accuracy: 0.9245283018867925
# Test Accuracy of the model on the 54 test images: 90.74074074074075 %
# Test Accuracy of the model on the 53 validation images: 92.45283018867924 %

# %%
plt.rcParams["figure.figsize"] = (12,8)
fig, ax = plt.subplots()
plt.plot(train_acc_list, '-rx', label='Train Acc')
plt.plot(test_acc_list, '-gx', label='Test Acc')
plt.plot(val_acc_list, '-bx', label='Val Acc')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
#ax.tick_params('vals', colors='r')

# Get second axis
ax2 = ax.twinx()
plt.plot(train_loss_list, '--cx', label='Train Loss')
plt.plot(val_loss_list, '--yx', label='Val Loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Accuracy & Loss vs. No. of epochs');
